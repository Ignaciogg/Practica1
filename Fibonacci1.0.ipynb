# %% [markdown]
# # Primer Programa -  Ignacio Gil Garzón ex. 22041267

# %% [markdown]
# ## Cree un programa que calcule la secuencia de  fib de 40, 50, 80

# %% [markdown]
# ### La fórmula que he usado se basa en:

# %%
from IPython import display

# %%
display.Image("fib.PNG")

# %%
def fib(n):
    if n<=1:
        return n
    else:
        return (fib(n-1)+fib(n-2))

# %%
fib(30)
# Out:
# 832040

# %%
pwd
# Out:
# 'C:\\Users\\nacho\\Primeros programas Python'

# %%
# !git --version
# Out:
# git version 2.24.1.windows.2
